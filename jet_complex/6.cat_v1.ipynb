# %%
import warnings
warnings.simplefilter('ignore')

import gc

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd
pd.set_option('max_columns', 200)
pd.set_option('max_rows', 200)
pd.set_option('float_format', lambda x: '%.6f' % x)

from tqdm import tqdm
tqdm.pandas()

from sklearn.model_selection import StratifiedKFold, KFold, GroupKFold
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import label_binarize

from catboost import CatBoostClassifier

# %%
train = pd.read_pickle('train_04j16p.float16.pickle')
test = pd.read_pickle('test_04j16p.float16.pickle')

# %%
mapping_dict = {21:0, 1:1, 4:2, 5:3}
mapping_dict_inv = {0:21, 1:1, 2:4, 3:5}

# %%
train['label'] = train.label.map(mapping_dict)

# %%
use_features = [col for col in train.columns if col not in ['event_id', 'label']]

# %%
def run_cat(df_train, df_test, use_features):
    
    target = 'label'
    oof_pred = np.zeros((len(df_train), 4))
    y_pred = np.zeros((len(df_test), 4))
    
    folds = GroupKFold(n_splits=5)
    for fold, (tr_ind, val_ind) in enumerate(folds.split(train, train['label'], train['event_id'])):
        print(f'Fold {fold + 1}')
        x_train, x_val = df_train[use_features].iloc[tr_ind], df_train[use_features].iloc[val_ind]
        y_train, y_val = df_train[target].iloc[tr_ind], df_train[target].iloc[val_ind]
        
        params = {
            'task_type': 'GPU',
            'learning_rate': 0.1,
            'eval_metric': 'MultiClass',
            'loss_function': 'MultiClass',
            'classes_count': 4,
            'iterations': 6000,
            'random_seed': 1029,
            'max_depth': 8,
            'max_leaves': 64,
            'reg_lambda': 0.5,
            'early_stopping_rounds': 100
        }
        
        model = CatBoostClassifier(**params)
        
        model.fit(x_train,
                  y_train,
                  eval_set=(x_val, y_val),
                  verbose=100)
        oof_pred[val_ind] = model.predict_proba(x_val)
        y_pred += model.predict_proba(df_test[use_features]) / folds.n_splits
        
        y_one_hot = label_binarize(y_val, np.arange(4)) 
        oof_one_hot = label_binarize(oof_pred[val_ind].argmax(axis=1), np.arange(4)) 
        score = roc_auc_score(y_one_hot, oof_one_hot) 
        print('auc: ', score)
        
        del x_train, x_val, y_train, y_val
        gc.collect()
        
    return y_pred, oof_pred

# %%
y_pred, oof_pred = run_cat(train, test, use_features)
# Out:
# Fold 1
# 0:	learn: -1.3398677	test: -1.3402443	best: -1.3402443 (0)	total: 151ms	remaining: 15m 5s
# 100:	learn: -0.9229606	test: -0.9287754	best: -0.9287754 (100)	total: 10.7s	remaining: 10m 22s
# 200:	learn: -0.8734323	test: -0.8844398	best: -0.8844398 (200)	total: 21s	remaining: 10m 4s
# 300:	learn: -0.8423594	test: -0.8585373	best: -0.8585373 (300)	total: 31.1s	remaining: 9m 48s
# 400:	learn: -0.8217837	test: -0.8433223	best: -0.8433223 (400)	total: 41.1s	remaining: 9m 34s
# 500:	learn: -0.8051491	test: -0.8320491	best: -0.8320491 (500)	total: 51s	remaining: 9m 20s
# 600:	learn: -0.7907867	test: -0.8231499	best: -0.8231499 (600)	total: 1m 1s	remaining: 9m 10s
# 700:	learn: -0.7797184	test: -0.8176188	best: -0.8176188 (700)	total: 1m 10s	remaining: 8m 56s
# 800:	learn: -0.7685218	test: -0.8118996	best: -0.8118996 (800)	total: 1m 20s	remaining: 8m 44s
# 900:	learn: -0.7584074	test: -0.8067992	best: -0.8067966 (899)	total: 1m 30s	remaining: 8m 32s
# 1000:	learn: -0.7495852	test: -0.8029700	best: -0.8029700 (1000)	total: 1m 40s	remaining: 8m 19s
# 1100:	learn: -0.7408591	test: -0.7991972	best: -0.7991972 (1100)	total: 1m 49s	remaining: 8m 7s
# 1200:	learn: -0.7340638	test: -0.7972613	best: -0.7972613 (1200)	total: 1m 59s	remaining: 7m 55s
# 1300:	learn: -0.7261230	test: -0.7940485	best: -0.7940485 (1300)	total: 2m 8s	remaining: 7m 44s
# 1400:	learn: -0.7190381	test: -0.7918000	best: -0.7918000 (1400)	total: 2m 18s	remaining: 7m 33s
# 1500:	learn: -0.7119167	test: -0.7894260	best: -0.7894260 (1500)	total: 2m 27s	remaining: 7m 22s
# 1600:	learn: -0.7049142	test: -0.7871825	best: -0.7871821 (1599)	total: 2m 37s	remaining: 7m 11s
# 1700:	learn: -0.6981072	test: -0.7851714	best: -0.7851714 (1700)	total: 2m 46s	remaining: 7m 2s
# 1800:	learn: -0.6918668	test: -0.7835564	best: -0.7835564 (1800)	total: 2m 56s	remaining: 6m 51s
# 1900:	learn: -0.6858762	test: -0.7821293	best: -0.7821293 (1900)	total: 3m 5s	remaining: 6m 40s
# 2000:	learn: -0.6793949	test: -0.7800241	best: -0.7800241 (2000)	total: 3m 15s	remaining: 6m 31s
# 2100:	learn: -0.6734874	test: -0.7787597	best: -0.7787452 (2099)	total: 3m 25s	remaining: 6m 20s
# 2200:	learn: -0.6674024	test: -0.7771500	best: -0.7771400 (2198)	total: 3m 34s	remaining: 6m 10s
# 2300:	learn: -0.6621004	test: -0.7761006	best: -0.7760848 (2299)	total: 3m 44s	remaining: 6m
# 2400:	learn: -0.6567816	test: -0.7752240	best: -0.7752240 (2400)	total: 3m 53s	remaining: 5m 50s
# 2500:	learn: -0.6512792	test: -0.7738799	best: -0.7738799 (2500)	total: 4m 3s	remaining: 5m 40s
# 2600:	learn: -0.6459759	test: -0.7730323	best: -0.7730323 (2600)	total: 4m 12s	remaining: 5m 30s
# 2700:	learn: -0.6407425	test: -0.7719630	best: -0.7719539 (2690)	total: 4m 22s	remaining: 5m 20s
# 2800:	learn: -0.6356549	test: -0.7711204	best: -0.7711204 (2800)	total: 4m 32s	remaining: 5m 10s
# 2900:	learn: -0.6304272	test: -0.7703134	best: -0.7703134 (2900)	total: 4m 41s	remaining: 5m 1s
# 3000:	learn: -0.6255962	test: -0.7698182	best: -0.7698182 (3000)	total: 4m 51s	remaining: 4m 51s
# 3100:	learn: -0.6207934	test: -0.7692047	best: -0.7691952 (3099)	total: 5m 1s	remaining: 4m 41s
# 3200:	learn: -0.6161470	test: -0.7685430	best: -0.7685387 (3199)	total: 5m 10s	remaining: 4m 31s
# 3300:	learn: -0.6111746	test: -0.7676239	best: -0.7676239 (3300)	total: 5m 20s	remaining: 4m 21s
# 3400:	learn: -0.6062099	test: -0.7666333	best: -0.7666121 (3384)	total: 5m 30s	remaining: 4m 12s
# 3500:	learn: -0.6018535	test: -0.7662630	best: -0.7662515 (3498)	total: 5m 39s	remaining: 4m 2s
# 3600:	learn: -0.5972727	test: -0.7655457	best: -0.7655402 (3591)	total: 5m 49s	remaining: 3m 52s
# 3700:	learn: -0.5927778	test: -0.7648758	best: -0.7648683 (3699)	total: 5m 59s	remaining: 3m 43s
# 3800:	learn: -0.5886232	test: -0.7645371	best: -0.7645200 (3798)	total: 6m 8s	remaining: 3m 33s
# 3900:	learn: -0.5842617	test: -0.7641137	best: -0.7640994 (3894)	total: 6m 18s	remaining: 3m 23s
# 4000:	learn: -0.5799812	test: -0.7634384	best: -0.7634363 (3999)	total: 6m 27s	remaining: 3m 13s
# 4100:	learn: -0.5757175	test: -0.7630458	best: -0.7630369 (4091)	total: 6m 37s	remaining: 3m 4s
# 4200:	learn: -0.5712881	test: -0.7625586	best: -0.7625343 (4185)	total: 6m 47s	remaining: 2m 54s
# 4300:	learn: -0.5671471	test: -0.7623726	best: -0.7623466 (4289)	total: 6m 57s	remaining: 2m 44s
# 4400:	learn: -0.5631084	test: -0.7621198	best: -0.7621198 (4400)	total: 7m 7s	remaining: 2m 35s
# 4500:	learn: -0.5590226	test: -0.7616753	best: -0.7616644 (4496)	total: 7m 16s	remaining: 2m 25s
# 4600:	learn: -0.5549170	test: -0.7612680	best: -0.7612567 (4599)	total: 7m 26s	remaining: 2m 15s
# 4700:	learn: -0.5510065	test: -0.7609616	best: -0.7609616 (4700)	total: 7m 36s	remaining: 2m 6s
# 4800:	learn: -0.5469841	test: -0.7605287	best: -0.7605287 (4800)	total: 7m 46s	remaining: 1m 56s
# 4900:	learn: -0.5430813	test: -0.7601636	best: -0.7601587 (4893)	total: 7m 55s	remaining: 1m 46s
# 5000:	learn: -0.5392669	test: -0.7598063	best: -0.7598063 (5000)	total: 8m 5s	remaining: 1m 36s
# 5100:	learn: -0.5354255	test: -0.7594755	best: -0.7594755 (5100)	total: 8m 15s	remaining: 1m 27s
# 5200:	learn: -0.5314169	test: -0.7589287	best: -0.7589266 (5196)	total: 8m 25s	remaining: 1m 17s
# 5300:	learn: -0.5277554	test: -0.7587092	best: -0.7587006 (5268)	total: 8m 34s	remaining: 1m 7s
# 5400:	learn: -0.5239339	test: -0.7584055	best: -0.7583877 (5393)	total: 8m 44s	remaining: 58.2s
# 5500:	learn: -0.5201278	test: -0.7580783	best: -0.7580708 (5498)	total: 8m 54s	remaining: 48.5s
# 5600:	learn: -0.5163287	test: -0.7578610	best: -0.7578556 (5599)	total: 9m 4s	remaining: 38.8s
# 5700:	learn: -0.5127977	test: -0.7576424	best: -0.7575924 (5671)	total: 9m 14s	remaining: 29.1s
# 5800:	learn: -0.5094427	test: -0.7575422	best: -0.7575374 (5799)	total: 9m 23s	remaining: 19.3s
# 5900:	learn: -0.5057444	test: -0.7571354	best: -0.7571312 (5891)	total: 9m 33s	remaining: 9.62s
# 5999:	learn: -0.5023705	test: -0.7568843	best: -0.7568622 (5990)	total: 9m 43s	remaining: 0us
# bestTest = -0.7568621804
# bestIteration = 5990
# Shrink model to first 5991 iterations.
# auc:  0.7956295723018628
# Fold 2
# 0:	learn: -1.3401150	test: -1.3398790	best: -1.3398790 (0)	total: 148ms	remaining: 14m 49s
# 100:	learn: -0.9235433	test: -0.9258427	best: -0.9258427 (100)	total: 10.6s	remaining: 10m 19s
# 200:	learn: -0.8720948	test: -0.8798421	best: -0.8798421 (200)	total: 20.7s	remaining: 9m 55s
# 300:	learn: -0.8426387	test: -0.8563561	best: -0.8563561 (300)	total: 30.7s	remaining: 9m 40s
# 400:	learn: -0.8204253	test: -0.8398436	best: -0.8398436 (400)	total: 40.6s	remaining: 9m 27s
# 500:	learn: -0.8018865	test: -0.8268378	best: -0.8268378 (500)	total: 50.6s	remaining: 9m 15s
# 600:	learn: -0.7893048	test: -0.8199377	best: -0.8199377 (600)	total: 1m	remaining: 9m
# 700:	learn: -0.7768983	test: -0.8128574	best: -0.8128574 (700)	total: 1m 9s	remaining: 8m 48s
# 800:	learn: -0.7654269	test: -0.8070137	best: -0.8070090 (799)	total: 1m 19s	remaining: 8m 35s
# 900:	learn: -0.7561621	test: -0.8035510	best: -0.8035510 (900)	total: 1m 29s	remaining: 8m 23s
# 1000:	learn: -0.7476247	test: -0.8006183	best: -0.8006183 (1000)	total: 1m 38s	remaining: 8m 11s
# 1100:	learn: -0.7397219	test: -0.7979171	best: -0.7979171 (1100)	total: 1m 47s	remaining: 7m 59s
# 1200:	learn: -0.7313805	test: -0.7943262	best: -0.7943262 (1200)	total: 1m 56s	remaining: 7m 46s
# 1300:	learn: -0.7231714	test: -0.7911371	best: -0.7911371 (1300)	total: 2m 6s	remaining: 7m 36s
# 1400:	learn: -0.7153764	test: -0.7883741	best: -0.7883741 (1400)	total: 2m 15s	remaining: 7m 26s
# 1500:	learn: -0.7085930	test: -0.7864439	best: -0.7864325 (1499)	total: 2m 25s	remaining: 7m 15s
# 1600:	learn: -0.7024657	test: -0.7851524	best: -0.7851524 (1600)	total: 2m 34s	remaining: 7m 4s
# 1700:	learn: -0.6964348	test: -0.7837757	best: -0.7837757 (1700)	total: 2m 43s	remaining: 6m 54s
# 1800:	learn: -0.6898170	test: -0.7816837	best: -0.7816837 (1800)	total: 2m 53s	remaining: 6m 43s
# 1900:	learn: -0.6837212	test: -0.7801317	best: -0.7801250 (1899)	total: 3m 2s	remaining: 6m 33s
# 2000:	learn: -0.6771607	test: -0.7781286	best: -0.7781244 (1999)	total: 3m 11s	remaining: 6m 23s
# 2100:	learn: -0.6709593	test: -0.7765252	best: -0.7765252 (2100)	total: 3m 21s	remaining: 6m 13s
# 2200:	learn: -0.6654111	test: -0.7756562	best: -0.7756562 (2200)	total: 3m 30s	remaining: 6m 3s
# 2300:	learn: -0.6600811	test: -0.7748408	best: -0.7748399 (2299)	total: 3m 39s	remaining: 5m 53s
# 2400:	learn: -0.6548808	test: -0.7740093	best: -0.7740019 (2399)	total: 3m 49s	remaining: 5m 43s
# 2500:	learn: -0.6494910	test: -0.7728984	best: -0.7728984 (2500)	total: 3m 58s	remaining: 5m 34s
# 2600:	learn: -0.6439729	test: -0.7715618	best: -0.7715618 (2600)	total: 4m 8s	remaining: 5m 24s
# 2700:	learn: -0.6389059	test: -0.7707569	best: -0.7707535 (2694)	total: 4m 17s	remaining: 5m 14s
# 2800:	learn: -0.6337441	test: -0.7700647	best: -0.7700647 (2800)	total: 4m 27s	remaining: 5m 5s
# 2900:	learn: -0.6286979	test: -0.7690824	best: -0.7690824 (2900)	total: 4m 36s	remaining: 4m 55s
# 3000:	learn: -0.6238224	test: -0.7684429	best: -0.7684351 (2999)	total: 4m 46s	remaining: 4m 46s
# 3100:	learn: -0.6192199	test: -0.7678754	best: -0.7678743 (3099)	total: 4m 55s	remaining: 4m 36s
# 3200:	learn: -0.6138870	test: -0.7663417	best: -0.7663349 (3199)	total: 5m 4s	remaining: 4m 26s
# 3300:	learn: -0.6095222	test: -0.7657533	best: -0.7657533 (3300)	total: 5m 13s	remaining: 4m 16s
# 3400:	learn: -0.6048890	test: -0.7653687	best: -0.7653639 (3397)	total: 5m 23s	remaining: 4m 7s
# 3500:	learn: -0.6002340	test: -0.7645845	best: -0.7645845 (3500)	total: 5m 32s	remaining: 3m 57s
# 3600:	learn: -0.5956219	test: -0.7641363	best: -0.7641363 (3600)	total: 5m 42s	remaining: 3m 48s
# 3700:	learn: -0.5910656	test: -0.7635333	best: -0.7635220 (3696)	total: 5m 51s	remaining: 3m 38s
# 3800:	learn: -0.5866505	test: -0.7631413	best: -0.7631413 (3800)	total: 6m 1s	remaining: 3m 29s
# 3900:	learn: -0.5823019	test: -0.7627658	best: -0.7627413 (3899)	total: 6m 11s	remaining: 3m 19s
# 4000:	learn: -0.5782419	test: -0.7624952	best: -0.7624936 (3999)	total: 6m 20s	remaining: 3m 10s
# 4100:	learn: -0.5740851	test: -0.7618588	best: -0.7618587 (4099)	total: 6m 30s	remaining: 3m
# 4200:	learn: -0.5698774	test: -0.7616251	best: -0.7616193 (4199)	total: 6m 39s	remaining: 2m 51s
# 4300:	learn: -0.5659020	test: -0.7611377	best: -0.7611363 (4298)	total: 6m 49s	remaining: 2m 41s
# 4400:	learn: -0.5617474	test: -0.7606005	best: -0.7606005 (4399)	total: 6m 58s	remaining: 2m 32s
# 4500:	learn: -0.5577516	test: -0.7603340	best: -0.7603340 (4500)	total: 7m 8s	remaining: 2m 22s
# 4600:	learn: -0.5535869	test: -0.7600269	best: -0.7600211 (4596)	total: 7m 18s	remaining: 2m 13s
# 4700:	learn: -0.5496692	test: -0.7595944	best: -0.7595739 (4691)	total: 7m 27s	remaining: 2m 3s
# 4800:	learn: -0.5460795	test: -0.7594747	best: -0.7594632 (4795)	total: 7m 36s	remaining: 1m 54s
# 4900:	learn: -0.5423976	test: -0.7593288	best: -0.7593090 (4892)	total: 7m 46s	remaining: 1m 44s
# 5000:	learn: -0.5386563	test: -0.7592625	best: -0.7591966 (4971)	total: 7m 55s	remaining: 1m 35s
# 5100:	learn: -0.5347371	test: -0.7589049	best: -0.7588974 (5085)	total: 8m 5s	remaining: 1m 25s
# 5200:	learn: -0.5310417	test: -0.7586252	best: -0.7585985 (5187)	total: 8m 15s	remaining: 1m 16s
# 5300:	learn: -0.5273446	test: -0.7583019	best: -0.7582994 (5298)	total: 8m 24s	remaining: 1m 6s
# 5400:	learn: -0.5236271	test: -0.7580336	best: -0.7580159 (5370)	total: 8m 34s	remaining: 57s
# 5500:	learn: -0.5200305	test: -0.7578218	best: -0.7578218 (5500)	total: 8m 43s	remaining: 47.5s
# 5600:	learn: -0.5161877	test: -0.7572243	best: -0.7572243 (5600)	total: 8m 53s	remaining: 38s
# 5700:	learn: -0.5127792	test: -0.7569971	best: -0.7569676 (5692)	total: 9m 3s	remaining: 28.5s
# 5800:	learn: -0.5089555	test: -0.7566398	best: -0.7566398 (5800)	total: 9m 12s	remaining: 19s
# 5900:	learn: -0.5053165	test: -0.7565388	best: -0.7565253 (5898)	total: 9m 22s	remaining: 9.44s
# 5999:	learn: -0.5019542	test: -0.7563481	best: -0.7563406 (5996)	total: 9m 32s	remaining: 0us
# bestTest = -0.7563405828
# bestIteration = 5996
# Shrink model to first 5997 iterations.
# auc:  0.7972595794483024
# Fold 3
# 0:	learn: -1.3399077	test: -1.3398555	best: -1.3398555 (0)	total: 142ms	remaining: 14m 10s
# 100:	learn: -0.9260153	test: -0.9334981	best: -0.9334981 (100)	total: 10.5s	remaining: 10m 12s
# 200:	learn: -0.8732961	test: -0.8858849	best: -0.8858849 (200)	total: 20.5s	remaining: 9m 50s
# 300:	learn: -0.8417373	test: -0.8593641	best: -0.8593641 (300)	total: 30.6s	remaining: 9m 39s
# 400:	learn: -0.8214477	test: -0.8446222	best: -0.8446222 (400)	total: 40.5s	remaining: 9m 25s
# 500:	learn: -0.8055144	test: -0.8338641	best: -0.8338641 (500)	total: 50.3s	remaining: 9m 12s
# 600:	learn: -0.7922372	test: -0.8256624	best: -0.8256624 (600)	total: 1m	remaining: 8m 59s
# 700:	learn: -0.7803935	test: -0.8189076	best: -0.8189076 (700)	total: 1m 9s	remaining: 8m 45s
# 800:	learn: -0.7695131	test: -0.8133626	best: -0.8133626 (800)	total: 1m 19s	remaining: 8m 33s
# 900:	learn: -0.7595308	test: -0.8086060	best: -0.8085989 (899)	total: 1m 28s	remaining: 8m 22s
# 1000:	learn: -0.7498749	test: -0.8038015	best: -0.8037982 (999)	total: 1m 38s	remaining: 8m 9s
# 1100:	learn: -0.7421520	test: -0.8011830	best: -0.8011830 (1100)	total: 1m 47s	remaining: 7m 58s
# 1200:	learn: -0.7341176	test: -0.7979927	best: -0.7979927 (1200)	total: 1m 56s	remaining: 7m 47s
# 1300:	learn: -0.7263704	test: -0.7949896	best: -0.7949896 (1300)	total: 2m 6s	remaining: 7m 35s
# 1400:	learn: -0.7195149	test: -0.7928332	best: -0.7928332 (1400)	total: 2m 15s	remaining: 7m 24s
# 1500:	learn: -0.7121128	test: -0.7904358	best: -0.7904358 (1500)	total: 2m 24s	remaining: 7m 14s
# 1600:	learn: -0.7051875	test: -0.7880543	best: -0.7880543 (1600)	total: 2m 34s	remaining: 7m 3s
# 1700:	learn: -0.6983863	test: -0.7859622	best: -0.7859544 (1699)	total: 2m 43s	remaining: 6m 53s
# 1800:	learn: -0.6920446	test: -0.7841319	best: -0.7841263 (1799)	total: 2m 53s	remaining: 6m 43s
# 1900:	learn: -0.6858978	test: -0.7826393	best: -0.7826377 (1899)	total: 3m 2s	remaining: 6m 33s
# 2000:	learn: -0.6801591	test: -0.7813946	best: -0.7813946 (2000)	total: 3m 12s	remaining: 6m 23s
# 2100:	learn: -0.6737483	test: -0.7794515	best: -0.7794515 (2100)	total: 3m 21s	remaining: 6m 13s
# 2200:	learn: -0.6680669	test: -0.7779059	best: -0.7778786 (2194)	total: 3m 30s	remaining: 6m 3s
# 2300:	learn: -0.6619331	test: -0.7761027	best: -0.7761027 (2300)	total: 3m 40s	remaining: 5m 53s
# 2400:	learn: -0.6569131	test: -0.7753019	best: -0.7753019 (2400)	total: 3m 49s	remaining: 5m 43s
# 2500:	learn: -0.6517009	test: -0.7743209	best: -0.7743182 (2499)	total: 3m 58s	remaining: 5m 33s
# 2600:	learn: -0.6465168	test: -0.7734695	best: -0.7734670 (2595)	total: 4m 8s	remaining: 5m 24s
# 2700:	learn: -0.6412298	test: -0.7721325	best: -0.7721150 (2698)	total: 4m 17s	remaining: 5m 14s
# 2800:	learn: -0.6361737	test: -0.7710614	best: -0.7710456 (2797)	total: 4m 26s	remaining: 5m 4s
# 2900:	learn: -0.6309404	test: -0.7701616	best: -0.7701503 (2898)	total: 4m 36s	remaining: 4m 55s
# 3000:	learn: -0.6259095	test: -0.7692789	best: -0.7692740 (2999)	total: 4m 45s	remaining: 4m 45s
# 3100:	learn: -0.6209844	test: -0.7683686	best: -0.7683686 (3100)	total: 4m 55s	remaining: 4m 35s
# 3200:	learn: -0.6160853	test: -0.7673421	best: -0.7673421 (3200)	total: 5m 4s	remaining: 4m 26s
# 3300:	learn: -0.6113441	test: -0.7666628	best: -0.7666497 (3292)	total: 5m 14s	remaining: 4m 16s
# 3400:	learn: -0.6065564	test: -0.7659197	best: -0.7659197 (3400)	total: 5m 23s	remaining: 4m 7s
# 3500:	learn: -0.6020258	test: -0.7652557	best: -0.7652479 (3498)	total: 5m 33s	remaining: 3m 57s
# 3600:	learn: -0.5977292	test: -0.7648028	best: -0.7648016 (3599)	total: 5m 42s	remaining: 3m 48s
# 3700:	learn: -0.5931757	test: -0.7640992	best: -0.7640992 (3700)	total: 5m 52s	remaining: 3m 38s
# 3800:	learn: -0.5887696	test: -0.7636611	best: -0.7636611 (3800)	total: 6m 1s	remaining: 3m 29s
# 3900:	learn: -0.5844281	test: -0.7631488	best: -0.7631488 (3900)	total: 6m 11s	remaining: 3m 19s
# 4000:	learn: -0.5801121	test: -0.7627592	best: -0.7627526 (3999)	total: 6m 20s	remaining: 3m 10s
# 4100:	learn: -0.5759794	test: -0.7625696	best: -0.7625441 (4096)	total: 6m 30s	remaining: 3m
# 4200:	learn: -0.5719030	test: -0.7619755	best: -0.7619755 (4200)	total: 6m 39s	remaining: 2m 51s
# 4300:	learn: -0.5676685	test: -0.7614976	best: -0.7614818 (4298)	total: 6m 49s	remaining: 2m 41s
# 4400:	learn: -0.5637388	test: -0.7611997	best: -0.7611693 (4377)	total: 6m 58s	remaining: 2m 32s
# 4500:	learn: -0.5596529	test: -0.7606677	best: -0.7606677 (4500)	total: 7m 8s	remaining: 2m 22s
# 4600:	learn: -0.5556251	test: -0.7601863	best: -0.7601838 (4599)	total: 7m 17s	remaining: 2m 13s
# 4700:	learn: -0.5516799	test: -0.7596241	best: -0.7596048 (4697)	total: 7m 27s	remaining: 2m 3s
# 4800:	learn: -0.5475966	test: -0.7589151	best: -0.7589102 (4799)	total: 7m 36s	remaining: 1m 54s
# 4900:	learn: -0.5436251	test: -0.7584151	best: -0.7584146 (4897)	total: 7m 46s	remaining: 1m 44s
# 5000:	learn: -0.5398850	test: -0.7579899	best: -0.7579820 (4999)	total: 7m 55s	remaining: 1m 34s
# 5100:	learn: -0.5362132	test: -0.7577225	best: -0.7577157 (5090)	total: 8m 4s	remaining: 1m 25s
# 5200:	learn: -0.5324558	test: -0.7574014	best: -0.7574014 (5192)	total: 8m 14s	remaining: 1m 15s
# 5300:	learn: -0.5288299	test: -0.7571670	best: -0.7571547 (5297)	total: 8m 23s	remaining: 1m 6s
# 5400:	learn: -0.5250779	test: -0.7568949	best: -0.7568949 (5400)	total: 8m 33s	remaining: 57s
# 5500:	learn: -0.5214042	test: -0.7566357	best: -0.7566357 (5500)	total: 8m 43s	remaining: 47.5s
# 5600:	learn: -0.5177563	test: -0.7565325	best: -0.7565039 (5594)	total: 8m 53s	remaining: 38s
# 5700:	learn: -0.5139428	test: -0.7561512	best: -0.7561512 (5700)	total: 9m 2s	remaining: 28.5s
# 5800:	learn: -0.5104405	test: -0.7560517	best: -0.7559991 (5794)	total: 9m 12s	remaining: 18.9s
# 5900:	learn: -0.5068253	test: -0.7558220	best: -0.7558004 (5894)	total: 9m 22s	remaining: 9.43s
# 5999:	learn: -0.5033774	test: -0.7556596	best: -0.7556130 (5972)	total: 9m 31s	remaining: 0us
# bestTest = -0.7556130091
# bestIteration = 5972
# Shrink model to first 5973 iterations.
# auc:  0.7960054440055587
# Fold 4
# 0:	learn: -1.3399348	test: -1.3402403	best: -1.3402403 (0)	total: 144ms	remaining: 14m 25s
# 100:	learn: -0.9234436	test: -0.9301906	best: -0.9301906 (100)	total: 10.4s	remaining: 10m 8s
# 200:	learn: -0.8720950	test: -0.8831931	best: -0.8831931 (200)	total: 20.4s	remaining: 9m 48s
# 300:	learn: -0.8407486	test: -0.8572574	best: -0.8572574 (300)	total: 30.5s	remaining: 9m 37s
# 400:	learn: -0.8216454	test: -0.8437326	best: -0.8437326 (400)	total: 40.3s	remaining: 9m 23s
# 500:	learn: -0.8050994	test: -0.8326740	best: -0.8326740 (500)	total: 50.1s	remaining: 9m 10s
# 600:	learn: -0.7904458	test: -0.8235097	best: -0.8235097 (600)	total: 1m	remaining: 8m 59s
# 700:	learn: -0.7777274	test: -0.8163217	best: -0.8163217 (700)	total: 1m 9s	remaining: 8m 48s
# 800:	learn: -0.7680338	test: -0.8121210	best: -0.8121210 (800)	total: 1m 19s	remaining: 8m 36s
# 900:	learn: -0.7587970	test: -0.8078561	best: -0.8078561 (900)	total: 1m 28s	remaining: 8m 22s
# 1000:	learn: -0.7490204	test: -0.8032993	best: -0.8032993 (1000)	total: 1m 38s	remaining: 8m 11s
# 1100:	learn: -0.7401558	test: -0.7995493	best: -0.7995493 (1100)	total: 1m 47s	remaining: 8m
# 1200:	learn: -0.7323873	test: -0.7964253	best: -0.7964253 (1200)	total: 1m 57s	remaining: 7m 48s
# 1300:	learn: -0.7250990	test: -0.7943431	best: -0.7943426 (1299)	total: 2m 6s	remaining: 7m 37s
# 1400:	learn: -0.7177206	test: -0.7919213	best: -0.7919213 (1400)	total: 2m 16s	remaining: 7m 26s
# 1500:	learn: -0.7108536	test: -0.7901040	best: -0.7901040 (1500)	total: 2m 25s	remaining: 7m 16s
# 1600:	learn: -0.7043317	test: -0.7884562	best: -0.7884562 (1600)	total: 2m 34s	remaining: 7m 5s
# 1700:	learn: -0.6971071	test: -0.7859352	best: -0.7859352 (1700)	total: 2m 44s	remaining: 6m 56s
# 1800:	learn: -0.6910070	test: -0.7844967	best: -0.7844967 (1800)	total: 2m 54s	remaining: 6m 46s
# 1900:	learn: -0.6849775	test: -0.7830106	best: -0.7830106 (1900)	total: 3m 3s	remaining: 6m 35s
# 2000:	learn: -0.6789410	test: -0.7814474	best: -0.7814474 (2000)	total: 3m 12s	remaining: 6m 25s
# 2100:	learn: -0.6731641	test: -0.7800813	best: -0.7800813 (2100)	total: 3m 22s	remaining: 6m 15s
# 2200:	learn: -0.6671121	test: -0.7784910	best: -0.7784686 (2195)	total: 3m 31s	remaining: 6m 5s
# 2300:	learn: -0.6615659	test: -0.7774076	best: -0.7774076 (2300)	total: 3m 41s	remaining: 5m 55s
# 2400:	learn: -0.6558040	test: -0.7760140	best: -0.7760140 (2400)	total: 3m 50s	remaining: 5m 45s
# 2500:	learn: -0.6505016	test: -0.7750889	best: -0.7750871 (2499)	total: 3m 59s	remaining: 5m 35s
# 2600:	learn: -0.6452551	test: -0.7739294	best: -0.7739294 (2600)	total: 4m 9s	remaining: 5m 25s
# 2700:	learn: -0.6403646	test: -0.7732232	best: -0.7732175 (2695)	total: 4m 18s	remaining: 5m 15s
# 2800:	learn: -0.6354666	test: -0.7724327	best: -0.7724143 (2793)	total: 4m 27s	remaining: 5m 5s
# 2900:	learn: -0.6306619	test: -0.7718174	best: -0.7718168 (2898)	total: 4m 37s	remaining: 4m 56s
# 3000:	learn: -0.6252147	test: -0.7705577	best: -0.7705508 (2999)	total: 4m 47s	remaining: 4m 46s
# 3100:	learn: -0.6203036	test: -0.7699474	best: -0.7699361 (3095)	total: 4m 56s	remaining: 4m 37s
# 3200:	learn: -0.6157437	test: -0.7695038	best: -0.7694998 (3198)	total: 5m 5s	remaining: 4m 27s
# 3300:	learn: -0.6111112	test: -0.7689949	best: -0.7689939 (3299)	total: 5m 15s	remaining: 4m 17s
# 3400:	learn: -0.6061831	test: -0.7680657	best: -0.7680657 (3400)	total: 5m 24s	remaining: 4m 8s
# 3500:	learn: -0.6015132	test: -0.7675094	best: -0.7674692 (3485)	total: 5m 34s	remaining: 3m 58s
# 3600:	learn: -0.5968864	test: -0.7667092	best: -0.7666886 (3598)	total: 5m 43s	remaining: 3m 48s
# 3700:	learn: -0.5924492	test: -0.7662303	best: -0.7662286 (3699)	total: 5m 53s	remaining: 3m 39s
# 3800:	learn: -0.5877438	test: -0.7654937	best: -0.7654937 (3800)	total: 6m 2s	remaining: 3m 29s
# 3900:	learn: -0.5833617	test: -0.7649857	best: -0.7649679 (3878)	total: 6m 12s	remaining: 3m 20s
# 4000:	learn: -0.5791632	test: -0.7647559	best: -0.7646795 (3969)	total: 6m 21s	remaining: 3m 10s
# 4100:	learn: -0.5747092	test: -0.7642967	best: -0.7642967 (4100)	total: 6m 31s	remaining: 3m 1s
# 4200:	learn: -0.5704345	test: -0.7637308	best: -0.7637123 (4183)	total: 6m 40s	remaining: 2m 51s
# 4300:	learn: -0.5660358	test: -0.7630497	best: -0.7630468 (4299)	total: 6m 50s	remaining: 2m 41s
# 4400:	learn: -0.5620275	test: -0.7626577	best: -0.7626552 (4399)	total: 6m 59s	remaining: 2m 32s
# 4500:	learn: -0.5580459	test: -0.7623987	best: -0.7623954 (4499)	total: 7m 9s	remaining: 2m 22s
# 4600:	learn: -0.5541042	test: -0.7623467	best: -0.7623466 (4517)	total: 7m 18s	remaining: 2m 13s
# 4700:	learn: -0.5503317	test: -0.7623481	best: -0.7623239 (4646)	total: 7m 28s	remaining: 2m 3s
# 4800:	learn: -0.5462553	test: -0.7616566	best: -0.7616497 (4789)	total: 7m 37s	remaining: 1m 54s
# 4900:	learn: -0.5423789	test: -0.7613864	best: -0.7613864 (4900)	total: 7m 47s	remaining: 1m 44s
# 5000:	learn: -0.5385472	test: -0.7611028	best: -0.7610913 (4998)	total: 7m 56s	remaining: 1m 35s
# 5100:	learn: -0.5345497	test: -0.7607659	best: -0.7607075 (5085)	total: 8m 6s	remaining: 1m 25s
# 5200:	learn: -0.5307925	test: -0.7603492	best: -0.7603351 (5199)	total: 8m 15s	remaining: 1m 16s
# 5300:	learn: -0.5268770	test: -0.7600979	best: -0.7600859 (5293)	total: 8m 25s	remaining: 1m 6s
# 5400:	learn: -0.5232201	test: -0.7596567	best: -0.7596515 (5392)	total: 8m 35s	remaining: 57.1s
# 5500:	learn: -0.5195274	test: -0.7593684	best: -0.7593642 (5499)	total: 8m 44s	remaining: 47.6s
# 5600:	learn: -0.5157186	test: -0.7590649	best: -0.7590578 (5590)	total: 8m 54s	remaining: 38.1s
# 5700:	learn: -0.5123209	test: -0.7589181	best: -0.7589152 (5693)	total: 9m 3s	remaining: 28.5s
# 5800:	learn: -0.5089305	test: -0.7587331	best: -0.7587039 (5786)	total: 9m 13s	remaining: 19s
# 5900:	learn: -0.5054501	test: -0.7585272	best: -0.7585029 (5867)	total: 9m 22s	remaining: 9.44s
# 5999:	learn: -0.5017506	test: -0.7582493	best: -0.7582493 (5999)	total: 9m 32s	remaining: 0us
# bestTest = -0.7582492742
# bestIteration = 5999
# Shrink model to first 6000 iterations.
# auc:  0.7948634485201069
# Fold 5
# 0:	learn: -1.3399826	test: -1.3402627	best: -1.3402627 (0)	total: 145ms	remaining: 14m 30s
# 100:	learn: -0.9237340	test: -0.9301853	best: -0.9301853 (100)	total: 10.5s	remaining: 10m 11s
# 200:	learn: -0.8699674	test: -0.8816207	best: -0.8816207 (200)	total: 20.5s	remaining: 9m 50s
# 300:	learn: -0.8421536	test: -0.8596379	best: -0.8596379 (300)	total: 30.6s	remaining: 9m 40s
# 400:	learn: -0.8213510	test: -0.8449298	best: -0.8449298 (400)	total: 40.7s	remaining: 9m 27s
# 500:	learn: -0.8055479	test: -0.8345487	best: -0.8345487 (500)	total: 50.4s	remaining: 9m 13s
# 600:	learn: -0.7923255	test: -0.8270143	best: -0.8270143 (600)	total: 60s	remaining: 8m 58s
# 700:	learn: -0.7789380	test: -0.8186117	best: -0.8186117 (700)	total: 1m 9s	remaining: 8m 46s
# 800:	learn: -0.7677022	test: -0.8128006	best: -0.8128006 (800)	total: 1m 19s	remaining: 8m 33s
# 900:	learn: -0.7573744	test: -0.8078192	best: -0.8078192 (900)	total: 1m 28s	remaining: 8m 21s
# 1000:	learn: -0.7485612	test: -0.8041282	best: -0.8041282 (1000)	total: 1m 37s	remaining: 8m 9s
# 1100:	learn: -0.7393154	test: -0.7999992	best: -0.7999990 (1099)	total: 1m 47s	remaining: 7m 58s
# 1200:	learn: -0.7314165	test: -0.7972351	best: -0.7972326 (1199)	total: 1m 56s	remaining: 7m 46s
# 1300:	learn: -0.7244399	test: -0.7953575	best: -0.7953437 (1299)	total: 2m 5s	remaining: 7m 34s
# 1400:	learn: -0.7161801	test: -0.7919597	best: -0.7919597 (1400)	total: 2m 15s	remaining: 7m 25s
# 1500:	learn: -0.7094662	test: -0.7900570	best: -0.7900558 (1498)	total: 2m 24s	remaining: 7m 14s
# 1600:	learn: -0.7023476	test: -0.7877199	best: -0.7877183 (1599)	total: 2m 34s	remaining: 7m 4s
# 1700:	learn: -0.6961917	test: -0.7862479	best: -0.7862250 (1693)	total: 2m 43s	remaining: 6m 53s
# 1800:	learn: -0.6900963	test: -0.7852145	best: -0.7852145 (1800)	total: 2m 53s	remaining: 6m 43s
# 1900:	learn: -0.6837134	test: -0.7836347	best: -0.7836330 (1899)	total: 3m 2s	remaining: 6m 33s
# 2000:	learn: -0.6775931	test: -0.7821930	best: -0.7821785 (1996)	total: 3m 12s	remaining: 6m 23s
# 2100:	learn: -0.6717738	test: -0.7809363	best: -0.7809233 (2097)	total: 3m 21s	remaining: 6m 13s
# 2200:	learn: -0.6661814	test: -0.7797831	best: -0.7797831 (2200)	total: 3m 30s	remaining: 6m 3s
# 2300:	learn: -0.6610160	test: -0.7789463	best: -0.7789463 (2300)	total: 3m 39s	remaining: 5m 53s
# 2400:	learn: -0.6557579	test: -0.7782720	best: -0.7782720 (2400)	total: 3m 48s	remaining: 5m 43s
# 2500:	learn: -0.6502466	test: -0.7770719	best: -0.7770719 (2500)	total: 3m 58s	remaining: 5m 33s
# 2600:	learn: -0.6447992	test: -0.7761476	best: -0.7761476 (2600)	total: 4m 7s	remaining: 5m 23s
# 2700:	learn: -0.6397116	test: -0.7752919	best: -0.7752858 (2699)	total: 4m 17s	remaining: 5m 14s
# 2800:	learn: -0.6346256	test: -0.7742047	best: -0.7742047 (2800)	total: 4m 26s	remaining: 5m 4s
# 2900:	learn: -0.6294967	test: -0.7735796	best: -0.7735796 (2900)	total: 4m 36s	remaining: 4m 55s
# 3000:	learn: -0.6248756	test: -0.7728622	best: -0.7728615 (2995)	total: 4m 45s	remaining: 4m 45s
# 3100:	learn: -0.6199967	test: -0.7721231	best: -0.7721231 (3100)	total: 4m 54s	remaining: 4m 35s
# 3200:	learn: -0.6150770	test: -0.7714849	best: -0.7714821 (3199)	total: 5m 4s	remaining: 4m 26s
# 3300:	learn: -0.6102135	test: -0.7706474	best: -0.7706474 (3300)	total: 5m 13s	remaining: 4m 16s
# 3400:	learn: -0.6055926	test: -0.7699804	best: -0.7699804 (3400)	total: 5m 23s	remaining: 4m 7s
# 3500:	learn: -0.6009703	test: -0.7692670	best: -0.7692562 (3497)	total: 5m 32s	remaining: 3m 57s
# 3600:	learn: -0.5962147	test: -0.7682779	best: -0.7682779 (3600)	total: 5m 42s	remaining: 3m 48s
# 3700:	learn: -0.5919982	test: -0.7681992	best: -0.7681589 (3629)	total: 5m 51s	remaining: 3m 38s
# 3800:	learn: -0.5874244	test: -0.7673810	best: -0.7673737 (3797)	total: 6m 1s	remaining: 3m 29s
# 3900:	learn: -0.5831885	test: -0.7670772	best: -0.7670744 (3898)	total: 6m 10s	remaining: 3m 19s
# 4000:	learn: -0.5784588	test: -0.7663040	best: -0.7662897 (3992)	total: 6m 20s	remaining: 3m 10s
# 4100:	learn: -0.5741625	test: -0.7654299	best: -0.7654236 (4092)	total: 6m 29s	remaining: 3m
# 4200:	learn: -0.5696126	test: -0.7646826	best: -0.7646659 (4198)	total: 6m 39s	remaining: 2m 51s
# 4300:	learn: -0.5653939	test: -0.7642939	best: -0.7642939 (4300)	total: 6m 49s	remaining: 2m 41s
# 4400:	learn: -0.5612524	test: -0.7638730	best: -0.7638730 (4400)	total: 6m 58s	remaining: 2m 32s
# 4500:	learn: -0.5573119	test: -0.7634858	best: -0.7634807 (4495)	total: 7m 8s	remaining: 2m 22s
# 4600:	learn: -0.5531779	test: -0.7630379	best: -0.7630178 (4594)	total: 7m 18s	remaining: 2m 13s
# 4700:	learn: -0.5492196	test: -0.7626356	best: -0.7626356 (4700)	total: 7m 27s	remaining: 2m 3s
# 4800:	learn: -0.5453384	test: -0.7622464	best: -0.7622464 (4800)	total: 7m 37s	remaining: 1m 54s
# 4900:	learn: -0.5413492	test: -0.7620451	best: -0.7620159 (4871)	total: 7m 46s	remaining: 1m 44s
# 5000:	learn: -0.5376564	test: -0.7617427	best: -0.7617376 (4997)	total: 7m 56s	remaining: 1m 35s
# 5100:	learn: -0.5338416	test: -0.7614943	best: -0.7614927 (5099)	total: 8m 5s	remaining: 1m 25s
# 5200:	learn: -0.5301178	test: -0.7612213	best: -0.7612146 (5199)	total: 8m 15s	remaining: 1m 16s
# 5300:	learn: -0.5262236	test: -0.7606150	best: -0.7606095 (5297)	total: 8m 24s	remaining: 1m 6s
# 5400:	learn: -0.5226116	test: -0.7603453	best: -0.7603453 (5400)	total: 8m 34s	remaining: 57s
# 5500:	learn: -0.5189452	test: -0.7600686	best: -0.7600625 (5481)	total: 8m 43s	remaining: 47.5s
# 5600:	learn: -0.5153677	test: -0.7599785	best: -0.7599292 (5590)	total: 8m 53s	remaining: 38s
# bestTest = -0.7599292115
# bestIteration = 5590
# Shrink model to first 5591 iterations.
# auc:  0.7947615918834294

# %%
y_one_hot = label_binarize(train['label'], np.arange(4)) 
oof_one_hot = label_binarize(oof_pred.argmax(axis=1), np.arange(4)) 
score = roc_auc_score(y_one_hot, oof_one_hot) 
print('auc: ', score)
# Out:
# auc:  0.795702682352037

# %%
test = pd.read_pickle('test_04j16p.float16.pickle')[['event_id']]
test["label"]= y_pred.argmax(axis=1)
test["label"] = test["label"].map({0:21, 1:1, 2:4, 3:5})
test.head()
# Out:
#                            event_id  label
# 0  fffecb31f40847b98e2175f689d535fb      5
# 1  fffe4696d3414a6288287e1b100c96c7      1
# 2  fffdee97573e44b2a51302dd74f78d78      5
# 3  fffdcc670e37433bb6227ea7d56dd29e      4
# 4  fffdbce9055843a5ae34ee9774e77454      1

# %%
submission = pd.read_csv('./jet_complex_data/complex_test_R04_jet.csv')[['jet_id', 'event_id']]
submission = pd.merge(submission, test, on=['event_id'])
submission = submission.drop(['event_id'], axis=1)
submission = submission.rename(columns={'jet_id': 'id'})
submission.head()
# Out:
#                                  id  label
# 0  cb3b5c6ea5e441e9b425fc1e6a4a00e6      5
# 1  ab8fc3fd74e643e68e070a391b8285c2      5
# 2  838bf5c3f9bc4a2194f51b3c57f403cd     21
# 3  f250685e3eee4e07ae31d851e72f4864     21
# 4  133b8f4676214e8191aa3a1da77439d4     21

# %%
submission.to_csv('submission_cat_0.795702682352037.csv', index=False)

# %%
np.save('y_pred_cat_0.795702682352037', y_pred)
np.save('oof_pred_cat_0.795702682352037', oof_pred)
